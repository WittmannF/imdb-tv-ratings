# %% [markdown]
# # IMDB Top 250 Series Exploratory Data Analysis
# Some questions we are interested in answering:
# - What are the top TV Series by their Mean Episode Rating?
#   - Also by their Median Episode Rating
# - What are the top TV Seasons by their Mean Episode Rating?
#   - Also by their Median Episode Rating
# - What are the most loved TV Series endings (with highest rating in the last episode)?
# - What are the most loved TV Series startings (with highest rating in the first episode)?
# - What are the TV Series that continusly keep improving (with highest slope in their ratings trend)?
# - What's the global distribution of episode ratings?
#   - Also global average and median?
#   - Which rage is above such average making it a "good episode"?
#   - What's the series with the highest number of "good episodes"?
# - Which series have a higher gap between their Mean Episode Rating and their TV Series Rating?

# %% [markdown]
# ## Prepare Data

# %%
import pandas as pd
import plotly.express as px

# %%
global_ratings = pd.read_csv('../input/top-250-imdb-series-episode-ratings/imdb_top_250_series_global_ratings.csv')
global_ratings = global_ratings.drop('Code.1', axis=1)
global_ratings.head()
# Out:
#         Code             Title  Rating Rating Count
# 0  tt5491994   Planet Earth II     9.4      142,844
# 1  tt0903747      Breaking Bad     9.4    1,817,275
# 2  tt0795176      Planet Earth     9.4      208,191
# 3  tt0185906  Band of Brothers     9.4      460,468
# 4  tt7366338         Chernobyl     9.3      729,461

# %%
episode_ratings = pd.read_csv(
    '../input/top-250-imdb-series-episode-ratings/imdb_top_250_series_episode_ratings.csv',
    index_col=0
)
episode_ratings.head()
# Out:
#    Season  Episode  Rating       Code            Title
# 0       1        1     9.4  tt5491994  Planet Earth II
# 1       1        2     9.1  tt5491994  Planet Earth II
# 2       1        3     8.9  tt5491994  Planet Earth II
# 3       1        4     8.8  tt5491994  Planet Earth II
# 4       1        5     8.6  tt5491994  Planet Earth II

# %%
global_ratings['IMDb Rank'] = range(1, 251)
global_ratings.head()
# Out:
#         Code             Title  Rating Rating Count  IMDb Rank
# 0  tt5491994   Planet Earth II     9.4      142,844          1
# 1  tt0903747      Breaking Bad     9.4    1,817,275          2
# 2  tt0795176      Planet Earth     9.4      208,191          3
# 3  tt0185906  Band of Brothers     9.4      460,468          4
# 4  tt7366338         Chernobyl     9.3      729,461          5

# %%
data = episode_ratings[['Season', 'Episode', 'Rating', 'Code']].rename({'Rating': 'Episode Rating'}, axis=1).join(
    global_ratings.set_index('Code'), 
    on='Code'
).rename({'Rating': 'Global Series Rating'}, axis=1)

data.head()
# Out:
#    Season  Episode  Episode Rating       Code            Title  \
# 0       1        1             9.4  tt5491994  Planet Earth II
# 1       1        2             9.1  tt5491994  Planet Earth II
# 2       1        3             8.9  tt5491994  Planet Earth II
# 3       1        4             8.8  tt5491994  Planet Earth II
# 4       1        5             8.6  tt5491994  Planet Earth II
#
#    Global Series Rating Rating Count  IMDb Rank
# 0                   9.4      142,844          1
# 1                   9.4      142,844          1
# 2                   9.4      142,844          1
# 3                   9.4      142,844          1
# 4                   9.4      142,844          1

# %%
data['Rating Count'] = data['Rating Count'].apply(lambda x: x.replace(',', '')).astype(int)

# %% [markdown]
# ## What are the top TV Series by their Mean Episode Rating

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

view = data.groupby(['Code', 'Title']).mean()[
    ['Episode Rating', 'Global Series Rating', 'IMDb Rank', 'Rating Count']
].sort_values(
    'Episode Rating', 
    ascending=False
).copy()

view = view.reset_index()

view['url'] = view['Code'].apply(lambda x: 'https://www.imdb.com/title/'+x)

view[['IMDb Rank', 'Rating Count']] = view[['IMDb Rank', 'Rating Count']].astype(int)
view = view.drop('Code', axis=1)
view = view.rename({'Episode Rating': 'Mean Episode Rating'}, axis=1)
view.head(15).style.format({'url': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_733e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Title</th>
#       <th class="col_heading level0 col1" >Mean Episode Rating</th>
#       <th class="col_heading level0 col2" >Global Series Rating</th>
#       <th class="col_heading level0 col3" >IMDb Rank</th>
#       <th class="col_heading level0 col4" >Rating Count</th>
#       <th class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_733e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_733e8_row0_col0" class="data row0 col0" >Chernobyl</td>
#       <td id="T_733e8_row0_col1" class="data row0 col1" >9.540000</td>
#       <td id="T_733e8_row0_col2" class="data row0 col2" >9.300000</td>
#       <td id="T_733e8_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_733e8_row0_col4" class="data row0 col4" >729461</td>
#       <td id="T_733e8_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.imdb.com/title/tt7366338">https://www.imdb.com/title/tt7366338</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_733e8_row1_col0" class="data row1 col0" >Aspirants</td>
#       <td id="T_733e8_row1_col1" class="data row1 col1" >9.280000</td>
#       <td id="T_733e8_row1_col2" class="data row1 col2" >8.600000</td>
#       <td id="T_733e8_row1_col3" class="data row1 col3" >123</td>
#       <td id="T_733e8_row1_col4" class="data row1 col4" >295762</td>
#       <td id="T_733e8_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.imdb.com/title/tt14392248">https://www.imdb.com/title/tt14392248</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_733e8_row2_col0" class="data row2 col0" >Attack on Titan</td>
#       <td id="T_733e8_row2_col1" class="data row2 col1" >9.140230</td>
#       <td id="T_733e8_row2_col2" class="data row2 col2" >8.900000</td>
#       <td id="T_733e8_row2_col3" class="data row2 col3" >26</td>
#       <td id="T_733e8_row2_col4" class="data row2 col4" >360876</td>
#       <td id="T_733e8_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.imdb.com/title/tt2560140">https://www.imdb.com/title/tt2560140</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_733e8_row3_col0" class="data row3 col0" >The Beatles: Get Back</td>
#       <td id="T_733e8_row3_col1" class="data row3 col1" >9.133333</td>
#       <td id="T_733e8_row3_col2" class="data row3 col2" >8.900000</td>
#       <td id="T_733e8_row3_col3" class="data row3 col3" >36</td>
#       <td id="T_733e8_row3_col4" class="data row3 col4" >21612</td>
#       <td id="T_733e8_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.imdb.com/title/tt9735318">https://www.imdb.com/title/tt9735318</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_733e8_row4_col0" class="data row4 col0" >The Last Dance</td>
#       <td id="T_733e8_row4_col1" class="data row4 col1" >9.100000</td>
#       <td id="T_733e8_row4_col2" class="data row4 col2" >9.000000</td>
#       <td id="T_733e8_row4_col3" class="data row4 col3" >17</td>
#       <td id="T_733e8_row4_col4" class="data row4 col4" >118827</td>
#       <td id="T_733e8_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.imdb.com/title/tt8420184">https://www.imdb.com/title/tt8420184</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_733e8_row5_col0" class="data row5 col0" >Ramayan</td>
#       <td id="T_733e8_row5_col1" class="data row5 col1" >9.065385</td>
#       <td id="T_733e8_row5_col2" class="data row5 col2" >8.500000</td>
#       <td id="T_733e8_row5_col3" class="data row5 col3" >156</td>
#       <td id="T_733e8_row5_col4" class="data row5 col4" >19898</td>
#       <td id="T_733e8_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.imdb.com/title/tt0268093">https://www.imdb.com/title/tt0268093</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_733e8_row6_col0" class="data row6 col0" >Gullak</td>
#       <td id="T_733e8_row6_col1" class="data row6 col1" >9.053333</td>
#       <td id="T_733e8_row6_col2" class="data row6 col2" >8.600000</td>
#       <td id="T_733e8_row6_col3" class="data row6 col3" >99</td>
#       <td id="T_733e8_row6_col4" class="data row6 col4" >16725</td>
#       <td id="T_733e8_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.imdb.com/title/tt10530900">https://www.imdb.com/title/tt10530900</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_733e8_row7_col0" class="data row7 col0" >Arcane</td>
#       <td id="T_733e8_row7_col1" class="data row7 col1" >9.044444</td>
#       <td id="T_733e8_row7_col2" class="data row7 col2" >8.900000</td>
#       <td id="T_733e8_row7_col3" class="data row7 col3" >24</td>
#       <td id="T_733e8_row7_col4" class="data row7 col4" >193782</td>
#       <td id="T_733e8_row7_col5" class="data row7 col5" ><a target="_blank" href="https://www.imdb.com/title/tt11126994">https://www.imdb.com/title/tt11126994</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_733e8_row8_col0" class="data row8 col0" >Scam 1992: The Harshad Mehta Story</td>
#       <td id="T_733e8_row8_col1" class="data row8 col1" >9.040000</td>
#       <td id="T_733e8_row8_col2" class="data row8 col2" >9.000000</td>
#       <td id="T_733e8_row8_col3" class="data row8 col3" >23</td>
#       <td id="T_733e8_row8_col4" class="data row8 col4" >142151</td>
#       <td id="T_733e8_row8_col5" class="data row8 col5" ><a target="_blank" href="https://www.imdb.com/title/tt12392504">https://www.imdb.com/title/tt12392504</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_733e8_row9_col0" class="data row9 col0" >Band of Brothers</td>
#       <td id="T_733e8_row9_col1" class="data row9 col1" >9.040000</td>
#       <td id="T_733e8_row9_col2" class="data row9 col2" >9.400000</td>
#       <td id="T_733e8_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_733e8_row9_col4" class="data row9 col4" >460468</td>
#       <td id="T_733e8_row9_col5" class="data row9 col5" ><a target="_blank" href="https://www.imdb.com/title/tt0185906">https://www.imdb.com/title/tt0185906</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_733e8_row10_col0" class="data row10 col0" >TVF Pitchers</td>
#       <td id="T_733e8_row10_col1" class="data row10 col1" >9.040000</td>
#       <td id="T_733e8_row10_col2" class="data row10 col2" >8.800000</td>
#       <td id="T_733e8_row10_col3" class="data row10 col3" >50</td>
#       <td id="T_733e8_row10_col4" class="data row10 col4" >67038</td>
#       <td id="T_733e8_row10_col5" class="data row10 col5" ><a target="_blank" href="https://www.imdb.com/title/tt4742876">https://www.imdb.com/title/tt4742876</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_733e8_row11_col0" class="data row11 col0" >Cosmos: A Spacetime Odyssey</td>
#       <td id="T_733e8_row11_col1" class="data row11 col1" >9.007692</td>
#       <td id="T_733e8_row11_col2" class="data row11 col2" >9.200000</td>
#       <td id="T_733e8_row11_col3" class="data row11 col3" >9</td>
#       <td id="T_733e8_row11_col4" class="data row11 col4" >121155</td>
#       <td id="T_733e8_row11_col5" class="data row11 col5" ><a target="_blank" href="https://www.imdb.com/title/tt2395695">https://www.imdb.com/title/tt2395695</a></td>
#     </tr>
#     <tr>
#       <th id="T_733e8_level0_row12" class="row_heading level0 row12" >12</th>

# %%
fig = px.bar(
    view.head(15).sort_values('Mean Episode Rating'),
    y='Title',
    x=['Global Series Rating', 'Mean Episode Rating'],
    barmode='group',
    hover_data=['IMDb Rank', 'Rating Count', 'url'],
    title='IMDb Rating vs Mean Episode Rating'
)
fig.update_xaxes(
    range=[8, 10],
    title='Rating'
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2155b46f-37ef-4171-ac29-8cdf15efc388" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

view = data.groupby(['Code', 'Title']).median()[
    ['Episode Rating', 'Global Series Rating', 'IMDb Rank', 'Rating Count']
].sort_values(
    'Episode Rating', 
    ascending=False
).copy()

view = view.reset_index()

view['url'] = view['Code'].apply(lambda x: 'https://www.imdb.com/title/'+x)

view[['IMDb Rank', 'Rating Count']] = view[['IMDb Rank', 'Rating Count']].astype(int)
view = view.drop('Code', axis=1)
view = view.rename({'Episode Rating': 'Median Episode Rating'}, axis=1)
view.head(15).style.format({'url': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c587_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Title</th>
#       <th class="col_heading level0 col1" >Median Episode Rating</th>
#       <th class="col_heading level0 col2" >Global Series Rating</th>
#       <th class="col_heading level0 col3" >IMDb Rank</th>
#       <th class="col_heading level0 col4" >Rating Count</th>
#       <th class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c587_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c587_row0_col0" class="data row0 col0" >Chernobyl</td>
#       <td id="T_7c587_row0_col1" class="data row0 col1" >9.500000</td>
#       <td id="T_7c587_row0_col2" class="data row0 col2" >9.300000</td>
#       <td id="T_7c587_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_7c587_row0_col4" class="data row0 col4" >729461</td>
#       <td id="T_7c587_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.imdb.com/title/tt7366338">https://www.imdb.com/title/tt7366338</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c587_row1_col0" class="data row1 col0" >Aspirants</td>
#       <td id="T_7c587_row1_col1" class="data row1 col1" >9.300000</td>
#       <td id="T_7c587_row1_col2" class="data row1 col2" >8.600000</td>
#       <td id="T_7c587_row1_col3" class="data row1 col3" >123</td>
#       <td id="T_7c587_row1_col4" class="data row1 col4" >295762</td>
#       <td id="T_7c587_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.imdb.com/title/tt14392248">https://www.imdb.com/title/tt14392248</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c587_row2_col0" class="data row2 col0" >Attack on Titan</td>
#       <td id="T_7c587_row2_col1" class="data row2 col1" >9.200000</td>
#       <td id="T_7c587_row2_col2" class="data row2 col2" >8.900000</td>
#       <td id="T_7c587_row2_col3" class="data row2 col3" >26</td>
#       <td id="T_7c587_row2_col4" class="data row2 col4" >360876</td>
#       <td id="T_7c587_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.imdb.com/title/tt2560140">https://www.imdb.com/title/tt2560140</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c587_row3_col0" class="data row3 col0" >Arcane</td>
#       <td id="T_7c587_row3_col1" class="data row3 col1" >9.200000</td>
#       <td id="T_7c587_row3_col2" class="data row3 col2" >8.900000</td>
#       <td id="T_7c587_row3_col3" class="data row3 col3" >24</td>
#       <td id="T_7c587_row3_col4" class="data row3 col4" >193782</td>
#       <td id="T_7c587_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.imdb.com/title/tt11126994">https://www.imdb.com/title/tt11126994</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c587_row4_col0" class="data row4 col0" >Ramayan</td>
#       <td id="T_7c587_row4_col1" class="data row4 col1" >9.100000</td>
#       <td id="T_7c587_row4_col2" class="data row4 col2" >8.500000</td>
#       <td id="T_7c587_row4_col3" class="data row4 col3" >156</td>
#       <td id="T_7c587_row4_col4" class="data row4 col4" >19898</td>
#       <td id="T_7c587_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.imdb.com/title/tt0268093">https://www.imdb.com/title/tt0268093</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c587_row5_col0" class="data row5 col0" >The Last Dance</td>
#       <td id="T_7c587_row5_col1" class="data row5 col1" >9.050000</td>
#       <td id="T_7c587_row5_col2" class="data row5 col2" >9.000000</td>
#       <td id="T_7c587_row5_col3" class="data row5 col3" >17</td>
#       <td id="T_7c587_row5_col4" class="data row5 col4" >118827</td>
#       <td id="T_7c587_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.imdb.com/title/tt8420184">https://www.imdb.com/title/tt8420184</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c587_row6_col0" class="data row6 col0" >Band of Brothers</td>
#       <td id="T_7c587_row6_col1" class="data row6 col1" >9.050000</td>
#       <td id="T_7c587_row6_col2" class="data row6 col2" >9.400000</td>
#       <td id="T_7c587_row6_col3" class="data row6 col3" >4</td>
#       <td id="T_7c587_row6_col4" class="data row6 col4" >460468</td>
#       <td id="T_7c587_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.imdb.com/title/tt0185906">https://www.imdb.com/title/tt0185906</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c587_row7_col0" class="data row7 col0" >The Beatles: Get Back</td>
#       <td id="T_7c587_row7_col1" class="data row7 col1" >9.000000</td>
#       <td id="T_7c587_row7_col2" class="data row7 col2" >8.900000</td>
#       <td id="T_7c587_row7_col3" class="data row7 col3" >36</td>
#       <td id="T_7c587_row7_col4" class="data row7 col4" >21612</td>
#       <td id="T_7c587_row7_col5" class="data row7 col5" ><a target="_blank" href="https://www.imdb.com/title/tt9735318">https://www.imdb.com/title/tt9735318</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c587_row8_col0" class="data row8 col0" >TVF Pitchers</td>
#       <td id="T_7c587_row8_col1" class="data row8 col1" >9.000000</td>
#       <td id="T_7c587_row8_col2" class="data row8 col2" >8.800000</td>
#       <td id="T_7c587_row8_col3" class="data row8 col3" >50</td>
#       <td id="T_7c587_row8_col4" class="data row8 col4" >67038</td>
#       <td id="T_7c587_row8_col5" class="data row8 col5" ><a target="_blank" href="https://www.imdb.com/title/tt4742876">https://www.imdb.com/title/tt4742876</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c587_row9_col0" class="data row9 col0" >Cosmos: A Spacetime Odyssey</td>
#       <td id="T_7c587_row9_col1" class="data row9 col1" >9.000000</td>
#       <td id="T_7c587_row9_col2" class="data row9 col2" >9.200000</td>
#       <td id="T_7c587_row9_col3" class="data row9 col3" >9</td>
#       <td id="T_7c587_row9_col4" class="data row9 col4" >121155</td>
#       <td id="T_7c587_row9_col5" class="data row9 col5" ><a target="_blank" href="https://www.imdb.com/title/tt2395695">https://www.imdb.com/title/tt2395695</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c587_row10_col0" class="data row10 col0" >Gullak</td>
#       <td id="T_7c587_row10_col1" class="data row10 col1" >9.000000</td>
#       <td id="T_7c587_row10_col2" class="data row10 col2" >8.600000</td>
#       <td id="T_7c587_row10_col3" class="data row10 col3" >99</td>
#       <td id="T_7c587_row10_col4" class="data row10 col4" >16725</td>
#       <td id="T_7c587_row10_col5" class="data row10 col5" ><a target="_blank" href="https://www.imdb.com/title/tt10530900">https://www.imdb.com/title/tt10530900</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c587_row11_col0" class="data row11 col0" >Scam 1992: The Harshad Mehta Story</td>
#       <td id="T_7c587_row11_col1" class="data row11 col1" >9.000000</td>
#       <td id="T_7c587_row11_col2" class="data row11 col2" >9.000000</td>
#       <td id="T_7c587_row11_col3" class="data row11 col3" >23</td>
#       <td id="T_7c587_row11_col4" class="data row11 col4" >142151</td>
#       <td id="T_7c587_row11_col5" class="data row11 col5" ><a target="_blank" href="https://www.imdb.com/title/tt12392504">https://www.imdb.com/title/tt12392504</a></td>
#     </tr>
#     <tr>
#       <th id="T_7c587_level0_row12" class="row_heading level0 row12" >12</th>

# %%
fig = px.bar(
    view.head(15).sort_values('Median Episode Rating'),
    y='Title',
    x=['Global Series Rating', 'Median Episode Rating'],
    barmode='group',
    hover_data=['IMDb Rank', 'Rating Count', 'url'],
    title='IMDb Rating vs Median Episode Rating'
)
fig.update_xaxes(
    range=[8, 10],
    title='Rating'
)
fig.show()
# Out:
# <div>                            <div id="33597091-ed18-491c-a522-3a216ff33668" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("